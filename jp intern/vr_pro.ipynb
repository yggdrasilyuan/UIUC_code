# %%
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_csv("D://stock_data/Nat_Gas.csv")
plt.plot(data.Dates,data.Prices)
plt.show


high level
target
spg
qr market
equtiy
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
