# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("output.csv")
df
# Out:
#     num_game  pratical    theory
# 0          0  0.000000  0.000000
# 1          1  0.144148  0.144000
# 2          2  0.220010  0.220032
# 3          3  0.263524  0.263105
# 4          4  0.289560  0.289343
# 5          5  0.307592  0.306453
# 6          6  0.318876  0.318288
# 7          7  0.327738  0.326874
# 8          8  0.334834  0.333337
# 9          9  0.339514  0.338339
# 10        10  0.343532  0.342291
# 11        11  0.345882  0.345460
# 12        12  0.347564  0.348031
# 13        13  0.350702  0.350131
# 14        14  0.351986  0.351855
# 15        15  0.353842  0.353272
# 16        16  0.355124  0.354437
# 17        17  0.355918  0.355392
# 18        18  0.356512  0.356169
# 19        19  0.357762  0.356796
# 20        20  0.358262  0.357293
# 21        21  0.358718  0.357680
# 22        22  0.358190  0.357969
# 23        23  0.359028  0.358175
# 24        24  0.359758  0.358306
# 25        25  0.359526  0.358373
# 26        26  0.359362  0.358382
# 27        27  0.359604  0.358340
# 28        28  0.359134  0.358253
# 29        29  0.359084  0.358125
# 30        30  0.359186  0.357838

# %%
plt.plot(df["num_game"],df["pratical"],label="Experiment")
plt.plot(df["num_game"],df["theory"],color="R",label="Theory")
plt.xlabel("Number of coin Tosses in Each Game")
plt.ylabel("Alice's Probability of winning")

plt.legend(bbox_to_anchor=(1.0, 1), loc=2, borderaxespad=0.)

# plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
